# %%
import numpy as np
import pandas as pd
from neo4j import GraphDatabase
from typing import List, Dict
import os
import streamlit as st
import re
import pandas as pd
import ast

# %% [markdown]
# ## Processing Raw Data(Scraped from course catalogue)

# %% [markdown]
# ## Opening and Specifying Directory

# %%
source_directory = 'data/raw'
target_directory = 'data/processed'

# Define the source and target directories
def is_graduate_course(title):
    match = re.search(r'\b\d{1,3}', title)  # Extract course number
    if match:
        course_number = int(match.group())  # Convert to integer
        return course_number >= 200  # Check if it's a graduate course
    return False  # If no number is found, consider it not a graduate course

# Split the title and extract the first two elements
def get_index(title):
    split_title = title.split()  # Split the title by spaces
    return " ".join(split_title[:2]).strip(".")  # Join the first two elements back into a string

def get_name(title):
    # Split the title by whitespace
    parts = title.split()
    
    # Remove the first two elements (course code and number)
    course_name_parts = parts[2:-1]  # Exclude the last element (e.g., '(4)')
    
    # Join the remaining parts to reconstruct the course name
    course_name = ' '.join(course_name_parts)
    
    return course_name

def get_unit(description):
    # Use regex to find the number inside parentheses
    match = re.search(r'\((\d+)\)', description)
    if match:
        return int(match.group(1))  # Convert the unit to an integer
    return None  # Return None if no unit is found

def get_tags(description):
    # Split the string by "Tags:" and check if tags exist
    if "Tags:" in description:
        tags_part = description.split("Tags:")[1]  # Extract the part after "Tags:"
        # Split tags into a list and strip any extra whitespace
        tags = [tag.strip() for tag in tags_part.split(',')]
        return tags
    return []  # Return an empty list if no tags are found

# %% [markdown]
# ## Extracting Key Informations(Prereqs, Units, Major Restrictions)

# %%
for file_name in os.listdir(source_directory):
    
    if file_name.endswith('.csv'):  # Only process CSV files
        prerequisites = []
        major_restrictions = []
        course_indexes = []
        course_units = []
        course_titles = []
        course_descriptions = []
        course_tags = []
        source_file_path = os.path.join(source_directory, file_name)
        target_file_path = os.path.join(target_directory, file_name)
        
        # Read the CSV file
        raw_data = pd.read_csv(source_file_path)
        data = raw_data[~raw_data['Title'].apply(is_graduate_course)]

        # Extract course titles into a list
        course_indexes = data['Title'].apply(get_index).tolist()
        course_titles = data['Title'].apply(get_name).tolist()
        course_units = data['Title'].apply(get_unit).tolist()
        course_tags = data['Title'].apply(get_tags).tolist()
        
        
        # Extract descriptions into a list
        course_descriptions = data['Description'].tolist()

        # Loop through the course descriptions to extract key info
        for description in course_descriptions:
            # Check for major restrictions
            if "restricted to" in description.lower():
                # Extract the part mentioning restricted majors
                match = re.search(r"restricted to (.+?)(?:\.|$)", description, re.IGNORECASE)
                if match:
                    restriction_text = match.group(1)
                    # Extract major codes (e.g., CS25, EC26)
                    majors = re.findall(r"[A-Z]{2}\d{2}", restriction_text)
                    
                    # Check if unrestricted condition is also mentioned
                    if "all other students will be allowed" in description.lower():
                        major_restrictions.append([])  # Unrestricted as space permits
                    else:
                        major_restrictions.append(majors)  # Only restricted to listed majors
                else:
                    major_restrictions.append([])  # No valid restriction found
            else:
                major_restrictions.append([])  # No restrictions mentioned
            
            # Match prerequisites that look like course numbers (e.g., "CSE 12", "MATH 10A")
            match = re.search(r"Prerequisite[s]*: (.+?)(?:\.|$)", description)
            if match:
                # Extract the part of the description mentioning prerequisites
                prereqs_text = match.group(1)
                # Use regex to find course numbers (e.g., "MATH 10A", "CSE 12")
                prereqs = re.findall(r"[A-Z]{2,4} \d+[A-Z]?", prereqs_text)
            else:
                prereqs = []  # No prerequisites found
            prerequisites.append(prereqs)
            
        # Display the results in a structured format
        structured_data = {
            "Course_Index": course_indexes,
            "Course_Title": course_titles,
            "Course_Units" : course_units,
            "Course_Description": course_descriptions,
            "Course_Prerequisites": prerequisites,
            "Major_Restriction" : major_restrictions, 
            "Course_Tags": course_tags
        }

        df_structured = pd.DataFrame(structured_data)
        df_structured.to_csv(target_file_path, index=False)
        
        
        print("Sent to", target_file_path)
# Out:
# Exception ignored in: <function Workspace.__del__ at 0x00000248E5DE7CE0>
# Traceback (most recent call last):
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\work\workspace.py", line 81, in __del__
#     self.close()
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\work\session.py", line 213, in close
#     self._connection.fetch_all()
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py", line 864, in fetch_all
#     detail_delta, summary_delta = self.fetch_message()
#                                   ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py", line 847, in fetch_message
#     tag, fields = self.inbox.pop(
#                   ^^^^^^^^^^^^^^^
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py", line 72, in pop
#     self._buffer_one_chunk()
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py", line 56, in _buffer_one_chunk
#     receive_into_buffer(
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py", line 323, in receive_into_buffer
#     buffer.data += bytearray(end - len(buffer.data))
# BufferError: Existing exports of data: object cannot be re-sized
# Exception ignored in: <function Workspace.__del__ at 0x00000248E5DE7CE0>
# Traceback (most recent call last):
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\work\workspace.py", line 81, in __del__
#     self.close()
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\work\session.py", line 213, in close
#     self._connection.fetch_all()
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py", line 864, in fetch_all
#     detail_delta, summary_delta = self.fetch_message()
#                                   ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py", line 847, in fetch_message
#     tag, fields = self.inbox.pop(
#                   ^^^^^^^^^^^^^^^
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py", line 72, in pop
#     self._buffer_one_chunk()
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py", line 56, in _buffer_one_chunk
#     receive_into_buffer(
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py", line 323, in receive_into_buffer
#     buffer.data += bytearray(end - len(buffer.data))
# BufferError: Existing exports of data: object cannot be re-sized
# Exception ignored in: <function Workspace.__del__ at 0x00000248E5DE7CE0>
# Traceback (most recent call last):
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\work\workspace.py", line 81, in __del__
#     self.close()
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\work\session.py", line 213, in close
#     self._connection.fetch_all()
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py", line 864, in fetch_all
#     detail_delta, summary_delta = self.fetch_message()
#                                   ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py", line 847, in fetch_message
#     tag, fields = self.inbox.pop(
#                   ^^^^^^^^^^^^^^^
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py", line 72, in pop
#     self._buffer_one_chunk()
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py", line 56, in _buffer_one_chunk
#     receive_into_buffer(
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py", line 323, in receive_into_buffer
#     buffer.data += bytearray(end - len(buffer.data))
# BufferError: Existing exports of data: object cannot be re-sized
# Exception ignored in: <function Workspace.__del__ at 0x00000248E5DE7CE0>
# Traceback (most recent call last):
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\work\workspace.py", line 81, in __del__
#     self.close()
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\work\session.py", line 213, in close
#     self._connection.fetch_all()
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py", line 864, in fetch_all
#     detail_delta, summary_delta = self.fetch_message()
#                                   ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py", line 847, in fetch_message
#     tag, fields = self.inbox.pop(
#                   ^^^^^^^^^^^^^^^
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py", line 72, in pop
#     self._buffer_one_chunk()
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py", line 56, in _buffer_one_chunk
#     receive_into_buffer(
#   File "c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py", line 323, in receive_into_buffer
#     buffer.data += bytearray(end - len(buffer.data))
# BufferError: Existing exports of data: object cannot be re-sized
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[136], line 16
#      14 # Read the CSV file
#      15 raw_data = pd.read_csv(source_file_path)
# ---> 16 data = raw_data[~raw_data['Title'].apply(is_graduate_course)]
#      18 # Extract course titles into a list
#      19 course_indexes = data['Title'].apply(get_index).tolist()
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Title'

# %%
class CourseDatabase:
    def __init__(self, uri: str, username: str, password: str):
        """Initialize connection to Neo4j database."""
        self.driver = GraphDatabase.driver(uri, auth=(username, password))

    def close(self):
        """Close the database connection."""
        self.driver.close()

    def add_course(self, code: str, name: str) -> None:
        """Add a new course to the database."""
        with self.driver.session() as session:
            session.execute_write(self._create_course, code, name)

    @staticmethod
    def _create_course(tx, code: str, name: str):
        query = """
        MERGE (c:Course {code: $code})
        SET c.name = $name
        RETURN c
        """
        result = tx.run(query, code=code, name=name)
        return result.single()

    def add_prerequisite(self, course_code: str, prereq_codes: list) -> None:
        """Add a prerequisite relationship between courses."""
        with self.driver.session() as session:
            session.execute_write(self._create_prerequisite, course_code, prereq_codes)

    @staticmethod
    def _create_prerequisite(tx, course_code: str, prereq_codes: list):
        query = """
        MATCH (c:Course {code: $course_code})
        UNWIND $prereq_codes AS prereq_code
        MATCH (p:Course {code: prereq_code})
        MERGE (c)-[:REQUIRES]->(p)
        """
        print("Relationship made", course_code)
        tx.run(query, course_code=course_code, prereq_codes=prereq_codes)

    def get_prerequisites(self, course_code: str, recursive: bool = True) -> List[Dict]:
        """Get prerequisites for a course. If recursive=True, get all indirect prerequisites as well."""
        with self.driver.session() as session:
            return session.execute_read(self._get_prerequisites, course_code, recursive)

    @staticmethod
    def _get_prerequisites(tx, course_code: str, recursive: bool):
        depth = "*" if recursive else "1"
        query = f"""
        MATCH (c:Course {{code: $code}})-[:REQUIRES{depth}]->(p:Course)
        RETURN p.code as code, p.name as name
        """
        result = tx.run(query, code=course_code)
        return [dict(record) for record in result]

    def get_available_courses(self, completed_courses: List[str]) -> List[Dict]:
        """Get courses where all prerequisites have been completed."""
        with self.driver.session() as session:
            return session.execute_read(self._get_available_courses, completed_courses)

    @staticmethod
    def _get_available_courses(tx, completed_courses: List[str]):
        query = """
        MATCH (c:Course)
        WHERE (
            // Either has no prerequisites
            NOT EXISTS((c)-[:REQUIRES]->(:Course))
            OR 
            // Or all prerequisites are completed
            ALL(prereq IN [(c)-[:REQUIRES]->(p) | p.code] 
                WHERE prereq IN $completed_courses)
        )
        // Exclude courses that are already completed
        AND NOT c.code IN $completed_courses
        RETURN c.code as code, c.name as name
        """
        result = tx.run(query, completed_courses=completed_courses)
        return [dict(record) for record in result]

# %%
uri = st.secrets["uri"]
username = st.secrets["username"]
password = st.secrets["password"]

db = CourseDatabase(
    uri=uri,
    username=username,
    password=password
)

# %% [markdown]
# ## Populating the Neo4j Database

# %%
source_directory = "data/processed/"
for file_name in os.listdir(source_directory):
    if file_name.endswith('.csv'):
        # Load the CSV file to examine its structure
        file_path = os.path.join(source_directory, file_name)
        print(file_path)
        data = pd.read_csv(file_path)

        courses = list(zip(data['Course_Index'], data['Course_Title']))
        prerequisites = list(zip(data['Course_Index'], data['Course_Prerequisites']))
        for code, name in courses:
            db.add_course(code, name)
        for code, prereq in prerequisites:
            print("Adding prereq", type(prereq))
            db.add_prerequisite(code, ast.literal_eval(prereq))
        print(file_path, "complete")
# Out:
# data/processed/CSE Course Data.csv
# C:\Users\theso\AppData\Local\Temp\ipykernel_7092\758587648.py:12: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with self.driver.session() as session:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:627, in Neo4jPool.fetch_routing_info(self, address, database, imp_user, bookmarks, auth, acquisition_timeout)
#     626 try:
# --> 627     routing_table = cx.route(
#     628         database=database or self.workspace_config.database,
#     629         imp_user=imp_user or self.workspace_config.impersonated_user,
#     630         bookmarks=bookmarks
#     631     )
#     632 finally:
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_bolt5.py:196, in Bolt5x0.route(self, database, imp_user, bookmarks, dehydration_hooks, hydration_hooks)
#     195 self.send_all()
# --> 196 self.fetch_all()
#     197 return [metadata.get("rt")]
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_all(self)
#     863 while not response.complete:
# --> 864     detail_delta, summary_delta = self.fetch_message()
#     865     detail_count += detail_delta
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#     846 # Receive exactly one message
# --> 847 tag, fields = self.inbox.pop(
#     848     hydration_hooks=self.responses[0].hydration_hooks
#     849 )
#     850 res = self._process_message(tag, fields)
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#      71 def pop(self, hydration_hooks):
# ---> 72     self._buffer_one_chunk()
#      73     try:
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py:51, in Inbox._buffer_one_chunk(self)
#      49 while chunk_size == 0:
#      50     # Determine the chunk size and skip noop
# ---> 51     receive_into_buffer(self._socket, self._buffer, 2)
#      52     chunk_size = self._buffer.pop_u16()
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py:326, in receive_into_buffer(sock, buffer, n_bytes)
#     325 while buffer.used < end:
# --> 326     n = sock.recv_into(view[buffer.used:end], end - buffer.used)
#     327     if n == 0:
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:493, in BoltSocket.recv_into(self, buffer, nbytes)
#     492 def recv_into(self, buffer, nbytes):
# --> 493     return self._wait_for_io(self._socket.recv_into, buffer, nbytes)
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_async_compat\network\_bolt_socket.py:468, in BoltSocket._wait_for_io(self, func, *args, **kwargs)
#     467 if self._deadline is None:
# --> 468     return func(*args, **kwargs)
#     469 timeout = self._socket.gettimeout()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1103 if buffer is not None:
# -> 1104     return self._sslobj.read(len, buffer)
#    1105 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# BufferError                               Traceback (most recent call last)
# Cell In[134], line 12
#      10 prerequisites = list(zip(data['Course_Index'], data['Course_Prerequisites']))
#      11 for code, name in courses:
# ---> 12     db.add_course(code, name)
#      13 for code, prereq in prerequisites:
#      14     print("Adding prereq", type(prereq))
#
# Cell In[30], line 13, in CourseDatabase.add_course(self, code, name)
#      11 """Add a new course to the database."""
#      12 with self.driver.session() as session:
# ---> 13     session.execute_write(self._create_course, code, name)
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\work\session.py:759, in Session.execute_write(self, transaction_function, *args, **kwargs)
#     708 @NonConcurrentMethodChecker.non_concurrent_method
#     709 def execute_write(
#     710     self,
#    (...)
#     714     *args: _P.args,  **kwargs: _P.kwargs
#     715 ) -> _R:
#     716     """Execute a unit of work in a managed write transaction.
#     717
#     718     .. note::
#    (...)
#     757     .. versionadded:: 5.0
#     758     """
# --> 759     return self._run_transaction(
#     760         WRITE_ACCESS, TelemetryAPI.TX_FUNC,
#     761         transaction_function, args, kwargs
#     762     )
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\work\session.py:545, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     543 while True:
#     544     try:
# --> 545         self._open_transaction(
#     546             tx_cls=ManagedTransaction,
#     547             api=None if telemetry_sent else api,
#     548             access_mode=access_mode, metadata=metadata,
#     549             timeout=timeout, api_success_cb=api_success_cb,
#     550         )
#     551         assert isinstance(self._transaction, ManagedTransaction)
#     552         tx = self._transaction
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\work\session.py:424, in Session._open_transaction(self, tx_cls, access_mode, api, metadata, timeout, api_success_cb)
#     413 def _open_transaction(
#     414     self,
#     415     *,
#    (...)
#     422     api_success_cb: t.Optional[t.Callable[[dict], None]] = None,
#     423 ) -> None:
# --> 424     self._connect(access_mode=access_mode)
#     425     assert self._connection is not None
#     426     if api is not None:
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\work\session.py:130, in Session._connect(self, access_mode, **acquire_kwargs)
#     128     access_mode = self._config.default_access_mode
#     129 try:
# --> 130     super()._connect(
#     131         access_mode, auth=self._config.auth, **acquire_kwargs
#     132     )
#     133 except asyncio.CancelledError:
#     134     self._handle_cancellation(message="_connect")
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\work\workspace.py:165, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     157     else:
#     158         # This is the first time we open a connection to a server in a
#     159         # cluster environment for this session without explicitly
#    (...)
#     162         # we shall use this database explicitly for all subsequent
#     163         # actions within this session.
#     164         log.debug("[#0000]  _: <WORKSPACE> resolve home database")
# --> 165         self._pool.update_routing_table(
#     166             database=self._config.database,
#     167             imp_user=self._config.impersonated_user,
#     168             bookmarks=self._get_bookmarks(),
#     169             auth=auth,
#     170             acquisition_timeout=acquisition_timeout,
#     171             database_callback=self._set_cached_database
#     172         )
#     173 acquire_kwargs_ = {
#     174     "access_mode": access_mode,
#     175     "timeout": acquisition_timeout,
#    (...)
#     179     "liveness_check_timeout": None,
#     180 }
#     181 acquire_kwargs_.update(acquire_kwargs)
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:774, in Neo4jPool.update_routing_table(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#     769 prefer_initial_routing_address = \
#     770     self.routing_tables[database].initialized_without_writers
#     772 if prefer_initial_routing_address:
#     773     # TODO: Test this state
# --> 774     if self._update_routing_table_from(
#     775         self.address, database=database,
#     776         imp_user=imp_user, bookmarks=bookmarks, auth=auth,
#     777         acquisition_timeout=acquisition_timeout,
#     778         database_callback=database_callback
#     779     ):
#     780         # Why is only the first initial routing address used?
#     781         return
#     782 if self._update_routing_table_from(
#     783     *(existing_routers - {self.address}), database=database,
#     784     imp_user=imp_user, bookmarks=bookmarks, auth=auth,
#     785     acquisition_timeout=acquisition_timeout,
#     786     database_callback=database_callback
#     787 ):
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:720, in Neo4jPool._update_routing_table_from(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback, *routers)
#     716 for router in routers:
#     717     for address in NetworkUtil.resolve_address(
#     718         router, resolver=self.pool_config.resolver
#     719     ):
# --> 720         new_routing_table = self.fetch_routing_table(
#     721             address=address, acquisition_timeout=acquisition_timeout,
#     722             database=database, imp_user=imp_user, bookmarks=bookmarks,
#     723             auth=auth
#     724         )
#     725         if new_routing_table is not None:
#     726             new_database = new_routing_table.database
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:657, in Neo4jPool.fetch_routing_table(self, address, acquisition_timeout, database, imp_user, bookmarks, auth)
#     655 new_routing_info = None
#     656 try:
# --> 657     new_routing_info = self.fetch_routing_info(
#     658         address, database, imp_user, bookmarks, auth,
#     659         acquisition_timeout
#     660     )
#     661 except Neo4jError as e:
#     662     # checks if the code is an error that is caused by the client. In
#     663     # this case there is no sense in trying to fetch a RT from another
#     664     # router. Hence, the driver should fail fast during discovery.
#     665     if e._is_fatal_during_discovery():
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:633, in Neo4jPool.fetch_routing_info(self, address, database, imp_user, bookmarks, auth, acquisition_timeout)
#     627     routing_table = cx.route(
#     628         database=database or self.workspace_config.database,
#     629         imp_user=imp_user or self.workspace_config.impersonated_user,
#     630         bookmarks=bookmarks
#     631     )
#     632 finally:
# --> 633     self.release(cx)
#     634 return routing_table
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_pool.py:372, in IOPool.release(self, *connections)
#     367 try:
#     368     log.debug(
#     369         "[#%04X]  _: <POOL> release unclean connection %s",
#     370         connection.local_port, connection.connection_id
#     371     )
# --> 372     connection.reset()
#     373 except (Neo4jError, DriverError, BoltError) as exc:
#     374     log.debug("[#%04X]  _: <POOL> failed to reset connection "
#     375               "on release: %r", connection.local_port, exc)
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_bolt5.py:323, in Bolt5x0.reset(self, dehydration_hooks, hydration_hooks)
#     320 self._append(b"\x0F", response=response,
#     321              dehydration_hooks=dehydration_hooks)
#     322 self.send_all()
# --> 323 self.fetch_all()
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_all(self)
#     862 response = self.responses[0]
#     863 while not response.complete:
# --> 864     detail_delta, summary_delta = self.fetch_message()
#     865     detail_count += detail_delta
#     866     summary_count += summary_delta
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_bolt.py:847, in Bolt.fetch_message(self)
#     844     return 0, 0
#     846 # Receive exactly one message
# --> 847 tag, fields = self.inbox.pop(
#     848     hydration_hooks=self.responses[0].hydration_hooks
#     849 )
#     850 res = self._process_message(tag, fields)
#     851 self.idle_since = monotonic()
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py:72, in Inbox.pop(self, hydration_hooks)
#      71 def pop(self, hydration_hooks):
# ---> 72     self._buffer_one_chunk()
#      73     try:
#      74         size, tag = self._unpacker.unpack_structure_header()
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py:56, in Inbox._buffer_one_chunk(self)
#      53     if chunk_size == 0:
#      54         log.debug("[#%04X]  S: <NOOP>", self._local_port)
# ---> 56 receive_into_buffer(
#      57     self._socket, self._buffer, chunk_size + 2
#      58 )
#      59 chunk_size = self._buffer.pop_u16()
#      61 if chunk_size == 0:
#      62     # chunk_size was the end marker for the message
#
# File c:\Users\theso\VSCODE Projects\llm-chatbot-python\.venv\Lib\site-packages\neo4j\_sync\io\_common.py:323, in receive_into_buffer(sock, buffer, n_bytes)
#     321 end = buffer.used + n_bytes
#     322 if end > len(buffer.data):
# --> 323     buffer.data += bytearray(end - len(buffer.data))
#     324 with memoryview(buffer.data) as view:
#     325     while buffer.used < end:
#
# BufferError: Existing exports of data: object cannot be re-sized

# %%
print("Prerequisites for MATH 154:")
prereqs = db.get_prerequisites("MATH 154")
for prereq in prereqs:
    print(f"- {prereq['code']}: {prereq['name']}")
# Out:
# Prerequisites for MATH 154:
# C:\Users\theso\AppData\Local\Temp\ipykernel_7092\758587648.py:41: DeprecationWarning: Using a driver after it has been closed is deprecated. Future versions of the driver will raise an error.
#   with self.driver.session() as session:

# %%
# print("Available courses (completed: CS101, MATH101):")
# available = db.get_available_courses(["CS101", "MATH101"])
# for course in available:
#     print(f"- {course['code']}: {course['name']}")
# Out:
# Available courses (completed: CS101, MATH101):
# - CS201: Data Structures
# - MATH201: Calculus II

# %%
db.close()
